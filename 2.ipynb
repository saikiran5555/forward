# %% [markdown]
# Forward propagation in a single-layer feedforward neural network involves calculating the output of the network based on the input and the parameters (weights and biases) of the network. Here's the mathematical implementation:
#
# Let's denote:
#
# �
# x as the input vector with
# �
# n elements
# �
# w as the weight vector with
# �
# n elements
# �
# b as the bias scalar
# �
# f as the activation function
# Then, the forward propagation process can be mathematically expressed as follows:
#
# Weighted sum of inputs and bias:
# �
# =
# ∑
# �
# =
# 1
# �
# �
# �
# ⋅
# �
# �
# +
# �
# z=∑
# i=1
# n
# ​
#  w
# i
# ​
#  ⋅x
# i
# ​
#  +b
#
# Activation function application:
# �
# =
# �
# (
# �
# )
# a=f(z)
#
# Where:
#
# �
# z is the weighted sum of inputs plus the bias.
# �
# a is the output of the neuron after applying the activation function
# �
# f to the weighted sum.
# Common activation functions include sigmoid, tanh, ReLU, etc., depending on the problem you are solving. This output
# �
# a can then be used as the output of the single-layer feedforward neural network.
